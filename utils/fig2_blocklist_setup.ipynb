# %%
### IMPORTANT ###
# DO NOT RUN THIS NOTEBOOK IF YOU ARE TRYING TO RECREATE THE FIGURES FROM THE PAPER!
# The code here is only to show how some raw data was acquired and/or post-processed.

# %% [markdown]
# ## Import

# %%
import numpy as np
import matplotlib.pyplot as plt
import requests
from requests.auth import HTTPBasicAuth
from bs4 import BeautifulSoup
import json
import pandas as pd
from fig2_blocklist_utils import *

# %% [markdown]
# ## Compile Censys Query

# %%
noprescriptionlist = [
   "no prescription required",
   "no prescription needed",
    "without prescription"
   "no rx needed",
   "no rx required",
   "no doctor visit",
]
# Expanded list of controlled substances (generic names and some popular ones)
CONTROLLED_SUBSTANCES = [
   "xanax",
   "valium",
   "tramadol",
   "oxycodone",
   "hydrocodone",
   "percocet",
   "adderall",
   "fentanyl",
   "morphine",
   "codeine",
   "hydromorphone",
   "oxymorphone",
   "dilaudid",
   "suboxone",
   "buprenorphine",
   "oxicontin",
   "vicodin",
   "roxicodone"
]

# Expanded list of brand names for common drugs
BRAND_NAMES = [
   "viagra",
   "cialis",
   "levitra",
   "kamagra",       # often sold illegally online
   "sildenafil",    # generic Viagra
   "tadalafil",     # generic Cialis
   "vardenafil",    # another ED medication
   "stendra"
]

noprescription = " OR ".join([f'"{k}"' for k in noprescriptionlist])
meds = " OR ".join([f'"{k}"' for k in (BRAND_NAMES + CONTROLLED_SUBSTANCES)])
query = f"({noprescription}) OR ({meds})"

# %%
# API keys
API_ID = "3ffa6ea5-5bdc-4c59-b7c6-39ba610974f3"
API_SECRET = "YVVoMmGbePCEqeIrZSwkiKe1yzC4poPB"

# query
url = "https://search.censys.io/api/v2/hosts/search"
cursor_next = ""
num_pages = 10

all_query_data = []
for i in range(num_pages):
    
    # setup parameters
    params = {
        "q": query,
    }
    if cursor_next != "":
        params["cursor"] = cursor_next

    # query
    response = requests.get(url, auth=HTTPBasicAuth(API_ID, API_SECRET), params=params)

    # format raw data
    data = response.json()
    cursor_next = data['result']['links']['next']

    # save
    print(data)
    all_query_data.append(data)

# # save to file
# with open('data/censys_manual.json', 'w') as f:
#     json.dump(all_query_data, f, indent=2)
# Out:
# {'code': 200, 'status': 'OK', 'result': {'query': '("no prescription required" OR "no prescription needed" OR "without prescriptionno rx needed" OR "no rx required" OR "no doctor visit") OR ("viagra" OR "cialis" OR "levitra" OR "kamagra" OR "sildenafil" OR "tadalafil" OR "vardenafil" OR "stendra" OR "xanax" OR "valium" OR "tramadol" OR "oxycodone" OR "hydrocodone" OR "percocet" OR "adderall" OR "fentanyl" OR "morphine" OR "codeine" OR "hydromorphone" OR "oxymorphone" OR "dilaudid" OR "suboxone" OR "buprenorphine" OR "oxicontin" OR "vicodin" OR "roxicodone")', 'total': 2940, 'duration': 333, 'hits': [{'location': {'postal_code': '34673', 'province': 'Florida', 'timezone': 'America/New_York', 'country': 'United States', 'continent': 'North America', 'coordinates': {'latitude': 28.27168, 'longitude': -82.71955}, 'country_code': 'US', 'city': 'Port Richey'}, 'last_updated_at': '2025-05-31T16:28:41.147Z', 'autonomous_system': {'description': 'ACEHOST', 'bgp_prefix': '209.216.89.0/24', 'asn': 398779, 'country_code': 'US', 'name': 'ACEHOST'}, 'ip': '209.216.89.128', 'operating_system': {'part': 'o', 'component_uniform_resource_identifiers': [], 'product': 'linux', 'other': [], 'cpe': 'cpe:2.3:o:*:linux:*:*:*:*:*:*:*:*', 'source': 'OSI_TRANSPORT_LAYER'}, 'services': [{'transport_protocol': 'TCP', 'extended_service_name': 'FTP', 'service_name': 'FTP', 'port': 21}, {'transport_protocol': 'UDP', 'extended_service_name': 'DNS', 'service_name': 'DNS', 'port': 53}, {'transport_protocol': 'TCP', 'extended_service_name': 'HTTP', 'service_name': 'HTTP', 'port': 80}, {'service_name': 'SMTP', 'transport_protocol': 'TCP', 'certificate': '983ef7424900b9423022d81295ccbd04b39919a48cf7ef1f17292b8a53c5cf46', 'extended_service_name': 'SMTP-STARTTLS', 'port': 587}, {'service_name': 'IMAP', 'transport_protocol': 'TCP', 'certificate': '2eac517ff463a4bc26668dbb92733783fcae591898a324e97e3fe3fab7416402', 'extended_service_name': 'IMAPS', 'port': 993}, {'extended_service_name': 'SMTP-STARTTLS', 'transport_protocol': 'TCP', 'service_name': 'SMTP', 'certificate': '983ef7424900b9423022d81295ccbd04b39919a48cf7ef1f17292b8a53c5cf46', 'port': 2525}, {'transport_protocol': 'TCP', 'extended_service_name': 'MYSQL', 'service_name': 'MYSQL', 'port': 3306}], 'matched_services': [{'transport_protocol': 'TCP', 'service_name': 'HTTP', 'extended_service_name': 'HTTP', 'port': 80}]}, {'location': {'coordinates': {'latitude': 51.51279, 'longitude': -0.09184}, 'province': 'England', 'timezone': 'Europe/London', 'country': 'United Kingdom', 'continent': 'Europe', 'city': 'City of London', 'country_code': 'GB', 'postal_code': 'E1W'}, 'last_updated_at': '2025-05-31T20:09:36.789Z', 'autonomous_system': {'description': 'OVH', 'bgp_prefix': '51.195.0.0/16', 'asn': 16276, 'country_code': 'FR', 'name': 'OVH'}, 'ip': '51.195.243.106', 'dns': {'reverse_dns': {'names': ['ip106.ip-51-195-243.eu']}}, 'operating_system': {'part': 'o', 'component_uniform_resource_identifiers': [], 'product': 'linux', 'other': [], 'cpe': 'cpe:2.3:o:*:linux:*:*:*:*:*:*:*:*', 'source': 'OSI_TRANSPORT_LAYER'}, 'services': [{'extended_service_name': 'FTPes', 'transport_protocol': 'TCP', 'service_name': 'FTP', 'certificate': '1d3dcec9e8af24ae8e8d0ebb01f04f3cb9b44e8c9b74ab05c9112d3236683987', 'port': 21}, {'transport_protocol': 'TCP', 'extended_service_name': 'SSH', 'service_name': 'SSH', 'port': 22}, {'service_name': 'SMTP', 'transport_protocol': 'TCP', 'certificate': '8bb36e73df97fd32d8077142ecd37f11786bf6cd078fbf2586276f5854b7247d', 'extended_service_name': 'SMTP-STARTTLS', 'port': 25}, {'transport_protocol': 'UDP', 'extended_service_name': 'DNS', 'service_name': 'DNS', 'port': 53}, {'transport_protocol': 'TCP', 'extended_service_name': 'HTTP', 'service_name': 'HTTP', 'port': 80}, {'service_name': 'POP3', 'transport_protocol': 'TCP', 'certificate': '8bb36e73df97fd32d8077142ecd37f11786bf6cd078fbf2586276f5854b7247d', 'extended_service_name': 'POP3S', 'port': 110}, {'service_name': 'IMAP', 'transport_protocol': 'TCP' ...
# {'code': 200, 'status': 'OK', 'result': {'query': '("no prescription required" OR "no prescription needed" OR "without prescriptionno rx needed" OR "no rx required" OR "no doctor visit") OR ("viagra" OR "cialis" OR "levitra" OR "kamagra" OR "sildenafil" OR "tadalafil" OR "vardenafil" OR "stendra" OR "xanax" OR "valium" OR "tramadol" OR "oxycodone" OR "hydrocodone" OR "percocet" OR "adderall" OR "fentanyl" OR "morphine" OR "codeine" OR "hydromorphone" OR "oxymorphone" OR "dilaudid" OR "suboxone" OR "buprenorphine" OR "oxicontin" OR "vicodin" OR "roxicodone")', 'total': 2941, 'duration': 376, 'hits': [{'operating_system': {'part': 'o', 'component_uniform_resource_identifiers': [], 'product': 'linux', 'other': [], 'cpe': 'cpe:2.3:o:*:linux:*:*:*:*:*:*:*:*', 'source': 'OSI_TRANSPORT_LAYER'}, 'last_updated_at': '2025-05-31T17:08:29.821Z', 'autonomous_system': {'description': 'Online SAS', 'bgp_prefix': '51.158.0.0/15', 'asn': 12876, 'country_code': 'FR', 'name': 'Online SAS'}, 'ip': '51.158.42.15', 'dns': {'reverse_dns': {'names': ['51-158-42-15.rev.poneytelecom.eu']}}, 'location': {'postal_code': '95200', 'province': 'Île-de-France', 'timezone': 'Europe/Paris', 'country': 'France', 'continent': 'Europe', 'coordinates': {'latitude': 48.99739, 'longitude': 2.37821}, 'country_code': 'FR', 'city': 'Sarcelles'}, 'services': [{'service_name': 'FTP', 'transport_protocol': 'TCP', 'certificate': 'b9141985a0f7baf28678dedcdd5e5df3886a1fd0fd9c9a5ba8cab58891ea3652', 'extended_service_name': 'FTPes', 'port': 21}, {'certificate': '8ff2622e4306fcc58ee42a9aa6e9ed6ac7f5f03f124e040cc8084a603f2bb4ed', 'transport_protocol': 'TCP', 'extended_service_name': 'SMTP-STARTTLS', 'service_name': 'SMTP', 'port': 25}, {'transport_protocol': 'UDP', 'extended_service_name': 'DNS', 'service_name': 'DNS', 'port': 53}, {'transport_protocol': 'TCP', 'service_name': 'HTTP', 'extended_service_name': 'HTTP', 'port': 80}, {'service_name': 'POP3', 'transport_protocol': 'TCP', 'certificate': '8ff2622e4306fcc58ee42a9aa6e9ed6ac7f5f03f124e040cc8084a603f2bb4ed', 'extended_service_name': 'POP3S', 'port': 110}, {'extended_service_name': 'IMAPS', 'transport_protocol': 'TCP', 'service_name': 'IMAP', 'certificate': '8ff2622e4306fcc58ee42a9aa6e9ed6ac7f5f03f124e040cc8084a603f2bb4ed', 'port': 143}, {'extended_service_name': 'SMTPS', 'transport_protocol': 'TCP', 'service_name': 'SMTP', 'certificate': '8ff2622e4306fcc58ee42a9aa6e9ed6ac7f5f03f124e040cc8084a603f2bb4ed', 'port': 465}, {'service_name': 'SMTP', 'transport_protocol': 'TCP', 'certificate': '8ff2622e4306fcc58ee42a9aa6e9ed6ac7f5f03f124e040cc8084a603f2bb4ed', 'extended_service_name': 'SMTP-STARTTLS', 'port': 587}, {'service_name': 'IMAP', 'transport_protocol': 'TCP', 'certificate': '8ff2622e4306fcc58ee42a9aa6e9ed6ac7f5f03f124e040cc8084a603f2bb4ed', 'extended_service_name': 'IMAPS', 'port': 993}, {'service_name': 'POP3', 'transport_protocol': 'TCP', 'certificate': '8ff2622e4306fcc58ee42a9aa6e9ed6ac7f5f03f124e040cc8084a603f2bb4ed', 'extended_service_name': 'POP3S', 'port': 995}], 'matched_services': [{'transport_protocol': 'TCP', 'service_name': 'HTTP', 'extended_service_name': 'HTTP', 'port': 80}]}, {'location': {'postal_code': 'LV-1001', 'province': 'Riga', 'timezone': 'Europe/Riga', 'country': 'Latvia', 'continent': 'Europe', 'coordinates': {'latitude': 56.946, 'longitude': 24.10589}, 'country_code': 'LV', 'city': 'Riga'}, 'last_updated_at': '2025-05-31T13:23:51.698Z', 'autonomous_system': {'description': 'MAKONIX', 'bgp_prefix': '185.82.126.0/23', 'asn': 52173, 'country_code': 'LV', 'name': 'MAKONIX'}, 'ip': '185.82.127.51', 'operating_system': {'part': 'o', 'component_uniform_resource_identifiers': [], 'product': 'linux', 'other': [], 'cpe': 'cpe:2.3:o:*:linux:*:*:*:*:*:*:*:*', 'source': 'OSI_TRANSPORT_LAYER'}, 'services': [{'transport_protocol': 'TCP', 'extended_service_name': 'FTP', 'service_name': 'FTP', 'port': 21}, {'transport_protocol': 'TCP', 'service_name': 'SSH', 'extended_service_name': 'SSH', 'port': 22}, {'transpor ...
# {'code': 200, 'status': 'OK', 'result': {'query': '("no prescription required" OR "no prescription needed" OR "without prescriptionno rx needed" OR "no rx required" OR "no doctor visit") OR ("viagra" OR "cialis" OR "levitra" OR "kamagra" OR "sildenafil" OR "tadalafil" OR "vardenafil" OR "stendra" OR "xanax" OR "valium" OR "tramadol" OR "oxycodone" OR "hydrocodone" OR "percocet" OR "adderall" OR "fentanyl" OR "morphine" OR "codeine" OR "hydromorphone" OR "oxymorphone" OR "dilaudid" OR "suboxone" OR "buprenorphine" OR "oxicontin" OR "vicodin" OR "roxicodone")', 'total': 2941, 'duration': 307, 'hits': [{'location': {'city': 'Frankfurt am Main', 'province': 'Hesse', 'timezone': 'Europe/Berlin', 'country': 'Germany', 'continent': 'Europe', 'postal_code': '60306', 'country_code': 'DE', 'coordinates': {'latitude': 50.11552, 'longitude': 8.68417}}, 'last_updated_at': '2025-05-31T20:57:51.059Z', 'autonomous_system': {'description': 'LEASEWEB-DE-FRA-10', 'bgp_prefix': '84.16.224.0/19', 'asn': 28753, 'country_code': 'DE', 'name': 'LEASEWEB-DE-FRA-10'}, 'ip': '84.16.226.140', 'operating_system': {'other': [], 'source': 'OSI_APPLICATION_LAYER', 'part': 'o', 'component_uniform_resource_identifiers': [], 'product': 'Linux', 'vendor': 'Ubuntu', 'cpe': 'cpe:2.3:o:canonical:ubuntu_linux:*:*:*:*:*:*:*:*'}, 'services': [{'transport_protocol': 'TCP', 'extended_service_name': 'HTTP', 'service_name': 'HTTP', 'port': 80}, {'service_name': 'HTTP', 'transport_protocol': 'TCP', 'certificate': '5a43cd6e367a91650ddf364812d9e38819ce5b7fbd0fd01dd258da88d711e73f', 'extended_service_name': 'HTTPS', 'port': 443}, {'transport_protocol': 'TCP', 'service_name': 'SSH', 'extended_service_name': 'SSH', 'port': 40022}], 'matched_services': [{'service_name': 'HTTP', 'transport_protocol': 'TCP', 'certificate': '5a43cd6e367a91650ddf364812d9e38819ce5b7fbd0fd01dd258da88d711e73f', 'extended_service_name': 'HTTPS', 'port': 443}]}, {'location': {'coordinates': {'latitude': 35.22709, 'longitude': -80.84313}, 'province': 'North Carolina', 'timezone': 'America/New_York', 'country': 'United States', 'continent': 'North America', 'city': 'Charlotte', 'country_code': 'US', 'postal_code': '28202'}, 'last_updated_at': '2025-05-31T16:20:52.244Z', 'autonomous_system': {'description': 'DC74-AS', 'bgp_prefix': '198.37.112.0/22', 'asn': 17216, 'country_code': 'US', 'name': 'DC74-AS'}, 'ip': '198.37.115.61', 'dns': {'reverse_dns': {'names': ['115.37.198-61.dc74.net']}}, 'operating_system': {'part': 'o', 'component_uniform_resource_identifiers': [], 'product': 'Linux', 'source': 'OSI_TRANSPORT_LAYER', 'cpe': 'cpe:2.3:o:*:linux:*:*:*:*:*:*:*:*', 'other': []}, 'services': [{'transport_protocol': 'TCP', 'extended_service_name': 'FTP', 'service_name': 'FTP', 'port': 21}, {'transport_protocol': 'TCP', 'extended_service_name': 'SSH', 'service_name': 'SSH', 'port': 22}, {'extended_service_name': 'SMTP-STARTTLS', 'transport_protocol': 'TCP', 'service_name': 'SMTP', 'certificate': 'f1c147a8d4eef9cfed8172775457d8b16ecc5f78cdb42b98f0c7fd6745d98def', 'port': 25}, {'transport_protocol': 'UDP', 'extended_service_name': 'DNS', 'service_name': 'DNS', 'port': 53}, {'transport_protocol': 'TCP', 'extended_service_name': 'HTTP', 'service_name': 'HTTP', 'port': 80}, {'transport_protocol': 'TCP', 'extended_service_name': 'HTTP', 'service_name': 'HTTP', 'port': 81}, {'service_name': 'POP3', 'transport_protocol': 'TCP', 'certificate': '899cbc4ed6959e3d8e1186de57ef242c60ff912a4f55a7e84480c553a353cebf', 'extended_service_name': 'POP3S', 'port': 110}, {'extended_service_name': 'IMAPS', 'transport_protocol': 'TCP', 'service_name': 'IMAP', 'certificate': '899cbc4ed6959e3d8e1186de57ef242c60ff912a4f55a7e84480c553a353cebf', 'port': 143}, {'service_name': 'HTTP', 'transport_protocol': 'TCP', 'certificate': '6916a5a04b31eee72378e0147aaa59d5414bca15ba32cd0e6859f3d42036660f', 'extended_service_name': 'HTTPS', 'port': 443}, {'service_name': 'SMTP', 'transport_protocol': 'TCP', 'certificate': 'f1c147a8d4eef9cfed8172775457d8b16 ...
# {'code': 200, 'status': 'OK', 'result': {'query': '("no prescription required" OR "no prescription needed" OR "without prescriptionno rx needed" OR "no rx required" OR "no doctor visit") OR ("viagra" OR "cialis" OR "levitra" OR "kamagra" OR "sildenafil" OR "tadalafil" OR "vardenafil" OR "stendra" OR "xanax" OR "valium" OR "tramadol" OR "oxycodone" OR "hydrocodone" OR "percocet" OR "adderall" OR "fentanyl" OR "morphine" OR "codeine" OR "hydromorphone" OR "oxymorphone" OR "dilaudid" OR "suboxone" OR "buprenorphine" OR "oxicontin" OR "vicodin" OR "roxicodone")', 'total': 2941, 'duration': 316, 'hits': [{'location': {'city': 'Lelystad', 'province': 'Flevoland', 'timezone': 'Europe/Amsterdam', 'country': 'Netherlands', 'continent': 'Europe', 'postal_code': '8224', 'country_code': 'NL', 'coordinates': {'latitude': 52.50833, 'longitude': 5.475}}, 'last_updated_at': '2025-05-26T10:44:48.241Z', 'autonomous_system': {'description': 'Online SAS', 'bgp_prefix': '195.154.0.0/16', 'asn': 12876, 'country_code': 'FR', 'name': 'Online SAS'}, 'ip': '195.154.60.252', 'dns': {'reverse_dns': {'names': ['195-154-60-252.rev.poneytelecom.eu']}}, 'operating_system': {'part': 'o', 'component_uniform_resource_identifiers': [], 'product': 'linux', 'source': 'OSI_TRANSPORT_LAYER', 'cpe': 'cpe:2.3:o:*:linux:*:*:*:*:*:*:*:*', 'other': []}, 'services': [{'certificate': '2a554bb1800bbde4b044c9d280b440cec36da930617edd46273aa50bd9080ba6', 'transport_protocol': 'TCP', 'extended_service_name': 'FTPes', 'service_name': 'FTP', 'port': 21}, {'transport_protocol': 'UDP', 'extended_service_name': 'DNS', 'service_name': 'DNS', 'port': 53}, {'transport_protocol': 'TCP', 'extended_service_name': 'HTTP', 'service_name': 'HTTP', 'port': 80}, {'transport_protocol': 'TCP', 'extended_service_name': 'PORTMAP', 'service_name': 'PORTMAP', 'port': 111}, {'transport_protocol': 'UDP', 'extended_service_name': 'PORTMAP', 'service_name': 'PORTMAP', 'port': 111}], 'matched_services': [{'transport_protocol': 'TCP', 'service_name': 'HTTP', 'extended_service_name': 'HTTP', 'port': 80}]}, {'location': {'postal_code': '10001', 'province': 'New York', 'timezone': 'America/New_York', 'country': 'United States', 'continent': 'North America', 'coordinates': {'latitude': 40.71427, 'longitude': -74.00597}, 'country_code': 'US', 'city': 'New York City'}, 'last_updated_at': '2025-05-31T14:07:28.986Z', 'autonomous_system': {'description': 'ECL-1', 'bgp_prefix': '66.11.120.0/24', 'asn': 23422, 'country_code': 'US', 'name': 'ECL-1'}, 'ip': '66.11.120.95', 'dns': {'reverse_dns': {'names': ['66-11-120-95.veportal.net']}}, 'operating_system': {'part': 'o', 'component_uniform_resource_identifiers': [], 'product': 'Linux', 'other': [], 'cpe': 'cpe:2.3:o:*:linux:*:*:*:*:*:*:*:*', 'source': 'OSI_TRANSPORT_LAYER'}, 'services': [{'transport_protocol': 'TCP', 'extended_service_name': 'FTP', 'service_name': 'FTP', 'port': 21}, {'transport_protocol': 'TCP', 'extended_service_name': 'SSH', 'service_name': 'SSH', 'port': 22}, {'transport_protocol': 'TCP', 'service_name': 'HTTP', 'extended_service_name': 'HTTP', 'port': 80}, {'transport_protocol': 'UDP', 'service_name': 'NTP', 'extended_service_name': 'NTP', 'port': 123}, {'transport_protocol': 'TCP', 'extended_service_name': 'UNKNOWN', 'service_name': 'UNKNOWN', 'port': 443}, {'transport_protocol': 'TCP', 'service_name': 'HTTP', 'extended_service_name': 'HTTP', 'port': 8080}], 'matched_services': [{'transport_protocol': 'TCP', 'extended_service_name': 'HTTP', 'service_name': 'HTTP', 'port': 8080}]}, {'operating_system': {'other': [{'key': 'family', 'value': 'Linux'}], 'source': 'OSI_APPLICATION_LAYER', 'part': 'o', 'component_uniform_resource_identifiers': [], 'product': 'Linux', 'vendor': 'Ubuntu', 'cpe': 'cpe:2.3:o:canonical:ubuntu_linux:*:*:*:*:*:*:*:*'}, 'last_updated_at': '2025-05-31T13:44:31.486Z', 'autonomous_system': {'description': 'ODIDO', 'bgp_prefix': '92.254.0.0/17', 'asn': 50266, 'country_code': 'NL', 'name': 'ODIDO'}, 'ip': '92.254.94.62', 'dns': {' ...
# {'code': 200, 'status': 'OK', 'result': {'query': '("no prescription required" OR "no prescription needed" OR "without prescriptionno rx needed" OR "no rx required" OR "no doctor visit") OR ("viagra" OR "cialis" OR "levitra" OR "kamagra" OR "sildenafil" OR "tadalafil" OR "vardenafil" OR "stendra" OR "xanax" OR "valium" OR "tramadol" OR "oxycodone" OR "hydrocodone" OR "percocet" OR "adderall" OR "fentanyl" OR "morphine" OR "codeine" OR "hydromorphone" OR "oxymorphone" OR "dilaudid" OR "suboxone" OR "buprenorphine" OR "oxicontin" OR "vicodin" OR "roxicodone")', 'total': 2941, 'duration': 333, 'hits': [{'operating_system': {'part': 'o', 'component_uniform_resource_identifiers': [], 'product': 'Linux', 'other': [], 'cpe': 'cpe:2.3:o:*:linux:*:*:*:*:*:*:*:*', 'source': 'OSI_TRANSPORT_LAYER'}, 'last_updated_at': '2025-05-30T23:54:32.451Z', 'autonomous_system': {'description': 'ITLDC-EU', 'bgp_prefix': '185.198.164.0/22', 'asn': 21100, 'country_code': 'US', 'name': 'ITLDC-EU'}, 'ip': '185.198.164.143', 'dns': {'reverse_dns': {'names': ['colma890.vds']}}, 'location': {'city': 'Meppel', 'province': 'Drenthe', 'timezone': 'Europe/Amsterdam', 'country': 'Netherlands', 'continent': 'Europe', 'postal_code': '7941', 'country_code': 'NL', 'coordinates': {'latitude': 52.69583, 'longitude': 6.19444}}, 'services': [{'service_name': 'SMTP', 'transport_protocol': 'TCP', 'certificate': '1901070b29b5407cb4f95c84c4744fdf9c46e11b5a8985ffc62bb0d15703e970', 'extended_service_name': 'SMTP-STARTTLS', 'port': 25}, {'transport_protocol': 'UDP', 'extended_service_name': 'DNS', 'service_name': 'DNS', 'port': 53}, {'transport_protocol': 'TCP', 'service_name': 'HTTP', 'extended_service_name': 'HTTP', 'port': 80}, {'transport_protocol': 'TCP', 'extended_service_name': 'HTTP', 'service_name': 'HTTP', 'port': 81}, {'service_name': 'POP3', 'transport_protocol': 'TCP', 'certificate': 'c5615dd5ecc51e3c3b38ccd1a5855ffbf66bbd5c6f054a9491ba28691ce80846', 'extended_service_name': 'POP3S', 'port': 110}, {'extended_service_name': 'IMAPS', 'transport_protocol': 'TCP', 'service_name': 'IMAP', 'certificate': 'c5615dd5ecc51e3c3b38ccd1a5855ffbf66bbd5c6f054a9491ba28691ce80846', 'port': 143}, {'certificate': '75155092b6f670aa0a403ac0d474121322a4eb5820330fd9237495028d445430', 'transport_protocol': 'TCP', 'extended_service_name': 'HTTPS', 'service_name': 'HTTP', 'port': 443}, {'service_name': 'SMTP', 'transport_protocol': 'TCP', 'certificate': '1901070b29b5407cb4f95c84c4744fdf9c46e11b5a8985ffc62bb0d15703e970', 'extended_service_name': 'SMTP-STARTTLS', 'port': 465}, {'service_name': 'IMAP', 'transport_protocol': 'TCP', 'certificate': 'c5615dd5ecc51e3c3b38ccd1a5855ffbf66bbd5c6f054a9491ba28691ce80846', 'extended_service_name': 'IMAPS', 'port': 993}, {'service_name': 'POP3', 'transport_protocol': 'TCP', 'certificate': 'c5615dd5ecc51e3c3b38ccd1a5855ffbf66bbd5c6f054a9491ba28691ce80846', 'extended_service_name': 'POP3S', 'port': 995}, {'transport_protocol': 'TCP', 'extended_service_name': 'SSH', 'service_name': 'SSH', 'port': 3333}], 'matched_services': [{'service_name': 'HTTP', 'transport_protocol': 'TCP', 'certificate': '75155092b6f670aa0a403ac0d474121322a4eb5820330fd9237495028d445430', 'extended_service_name': 'HTTPS', 'port': 443}, {'transport_protocol': 'TCP', 'extended_service_name': 'HTTP', 'service_name': 'HTTP', 'port': 80}, {'transport_protocol': 'TCP', 'extended_service_name': 'HTTP', 'service_name': 'HTTP', 'port': 81}]}, {'location': {'postal_code': '85001', 'province': 'Arizona', 'timezone': 'America/Phoenix', 'country': 'United States', 'continent': 'North America', 'coordinates': {'latitude': 33.44838, 'longitude': -112.07404}, 'country_code': 'US', 'city': 'Phoenix'}, 'last_updated_at': '2025-05-31T18:40:36.820Z', 'autonomous_system': {'description': 'GO-DADDY-COM-LLC', 'bgp_prefix': '23.229.184.0/22', 'asn': 398101, 'country_code': 'US', 'name': 'GO-DADDY-COM-LLC'}, 'ip': '23.229.184.67', 'dns': {'reverse_dns': {'names': ['67.184.229.23.host.secureserver.net']}}, 'opera ...
# {'code': 200, 'status': 'OK', 'result': {'query': '("no prescription required" OR "no prescription needed" OR "without prescriptionno rx needed" OR "no rx required" OR "no doctor visit") OR ("viagra" OR "cialis" OR "levitra" OR "kamagra" OR "sildenafil" OR "tadalafil" OR "vardenafil" OR "stendra" OR "xanax" OR "valium" OR "tramadol" OR "oxycodone" OR "hydrocodone" OR "percocet" OR "adderall" OR "fentanyl" OR "morphine" OR "codeine" OR "hydromorphone" OR "oxymorphone" OR "dilaudid" OR "suboxone" OR "buprenorphine" OR "oxicontin" OR "vicodin" OR "roxicodone")', 'total': 2941, 'duration': 353, 'hits': [{'location': {'coordinates': {'latitude': 59.93863, 'longitude': 30.31413}, 'province': 'St.-Petersburg', 'timezone': 'Europe/Moscow', 'country': 'Russia', 'continent': 'Europe', 'city': 'Saint Petersburg', 'country_code': 'RU', 'postal_code': '195213'}, 'last_updated_at': '2025-05-25T16:41:09.680Z', 'autonomous_system': {'description': 'TIMEWEB-AS', 'bgp_prefix': '81.200.148.0/24', 'asn': 9123, 'country_code': 'RU', 'name': 'TIMEWEB-AS'}, 'ip': '81.200.148.201', 'operating_system': {'part': 'o', 'component_uniform_resource_identifiers': [], 'product': 'linux', 'other': [], 'cpe': 'cpe:2.3:o:*:linux:*:*:*:*:*:*:*:*', 'source': 'OSI_TRANSPORT_LAYER'}, 'services': [{'transport_protocol': 'TCP', 'service_name': 'SSH', 'extended_service_name': 'SSH', 'port': 22}, {'transport_protocol': 'TCP', 'service_name': 'HTTP', 'extended_service_name': 'HTTP', 'port': 80}, {'service_name': 'HTTP', 'transport_protocol': 'TCP', 'certificate': 'fac02364b0c642e809ac4de2385d1e4439649da0fddd76f79bd9c4993348feeb', 'extended_service_name': 'HTTPS', 'port': 443}], 'matched_services': [{'extended_service_name': 'HTTPS', 'transport_protocol': 'TCP', 'service_name': 'HTTP', 'certificate': 'fac02364b0c642e809ac4de2385d1e4439649da0fddd76f79bd9c4993348feeb', 'port': 443}]}, {'location': {'postal_code': 'M5', 'province': 'England', 'timezone': 'Europe/London', 'country': 'United Kingdom', 'continent': 'Europe', 'coordinates': {'latitude': 53.48771, 'longitude': -2.29042}, 'country_code': 'GB', 'city': 'Salford'}, 'last_updated_at': '2025-05-31T09:16:30.849Z', 'autonomous_system': {'description': 'M247', 'bgp_prefix': '5.61.60.0/23', 'asn': 9009, 'country_code': 'RO', 'name': 'M247'}, 'ip': '5.61.60.205', 'operating_system': {'other': [{'key': 'family', 'value': 'Linux'}], 'source': 'OSI_APPLICATION_LAYER', 'part': 'o', 'component_uniform_resource_identifiers': [], 'product': 'Linux', 'vendor': 'Debian', 'cpe': 'cpe:2.3:o:debian:debian_linux:*:*:*:*:*:*:*:*'}, 'services': [{'extended_service_name': 'FTPes', 'transport_protocol': 'TCP', 'service_name': 'FTP', 'certificate': 'd015f23925e74e265a0c67acf0b4127d901242371e685eb242c0abcf654c436d', 'port': 21}, {'transport_protocol': 'TCP', 'service_name': 'SSH', 'extended_service_name': 'SSH', 'port': 22}, {'transport_protocol': 'UDP', 'extended_service_name': 'DNS', 'service_name': 'DNS', 'port': 53}, {'transport_protocol': 'TCP', 'extended_service_name': 'HTTP', 'service_name': 'HTTP', 'port': 80}, {'transport_protocol': 'UDP', 'extended_service_name': 'NTP', 'service_name': 'NTP', 'port': 123}, {'certificate': '88a44e38def535c694f8f0a692d646dee368697c4128e6fb40925db4c56a4d70', 'transport_protocol': 'TCP', 'extended_service_name': 'HTTPS', 'service_name': 'HTTP', 'port': 443}, {'service_name': 'HTTP', 'transport_protocol': 'TCP', 'certificate': '6547971d346c6e26ab46411d8e894b74e76cbcdfc5cc985d112bbcdddd86158f', 'extended_service_name': 'HTTPS', 'port': 1500}], 'matched_services': [{'service_name': 'HTTP', 'transport_protocol': 'TCP', 'certificate': '88a44e38def535c694f8f0a692d646dee368697c4128e6fb40925db4c56a4d70', 'extended_service_name': 'HTTPS', 'port': 443}]}, {'location': {'postal_code': '03027', 'province': 'Kyiv City', 'timezone': 'Europe/Kyiv', 'country': 'Ukraine', 'continent': 'Europe', 'coordinates': {'latitude': 50.45466, 'longitude': 30.5238}, 'country_code': 'UA', 'city': 'Kyiv'}, 'last_updated_at': '2025- ...
# {'code': 200, 'status': 'OK', 'result': {'query': '("no prescription required" OR "no prescription needed" OR "without prescriptionno rx needed" OR "no rx required" OR "no doctor visit") OR ("viagra" OR "cialis" OR "levitra" OR "kamagra" OR "sildenafil" OR "tadalafil" OR "vardenafil" OR "stendra" OR "xanax" OR "valium" OR "tramadol" OR "oxycodone" OR "hydrocodone" OR "percocet" OR "adderall" OR "fentanyl" OR "morphine" OR "codeine" OR "hydromorphone" OR "oxymorphone" OR "dilaudid" OR "suboxone" OR "buprenorphine" OR "oxicontin" OR "vicodin" OR "roxicodone")', 'total': 2941, 'duration': 345, 'hits': [{'operating_system': {'part': 'o', 'component_uniform_resource_identifiers': [], 'product': 'linux', 'other': [], 'cpe': 'cpe:2.3:o:*:linux:*:*:*:*:*:*:*:*', 'source': 'OSI_TRANSPORT_LAYER'}, 'last_updated_at': '2025-05-31T19:51:31.138Z', 'autonomous_system': {'description': 'YURTEH-AS', 'bgp_prefix': '62.182.82.0/23', 'asn': 30860, 'country_code': 'UA', 'name': 'YURTEH-AS'}, 'ip': '62.182.82.98', 'dns': {'reverse_dns': {'names': ['a2.jonaskle.com']}}, 'location': {'postal_code': '03027', 'province': 'Kyiv City', 'timezone': 'Europe/Kyiv', 'country': 'Ukraine', 'continent': 'Europe', 'coordinates': {'latitude': 50.45466, 'longitude': 30.5238}, 'country_code': 'UA', 'city': 'Kyiv'}, 'services': [{'certificate': 'af3e698630d34e665cd9712264a75a2e122069e98a90bf875760f7d4688ff374', 'transport_protocol': 'TCP', 'extended_service_name': 'FTPes', 'service_name': 'FTP', 'port': 21}, {'transport_protocol': 'TCP', 'extended_service_name': 'SSH', 'service_name': 'SSH', 'port': 22}, {'service_name': 'SMTP', 'transport_protocol': 'TCP', 'certificate': 'af3e698630d34e665cd9712264a75a2e122069e98a90bf875760f7d4688ff374', 'extended_service_name': 'SMTP-STARTTLS', 'port': 25}, {'transport_protocol': 'UDP', 'extended_service_name': 'DNS', 'service_name': 'DNS', 'port': 53}, {'transport_protocol': 'TCP', 'extended_service_name': 'HTTP', 'service_name': 'HTTP', 'port': 80}, {'service_name': 'POP3', 'transport_protocol': 'TCP', 'certificate': 'af3e698630d34e665cd9712264a75a2e122069e98a90bf875760f7d4688ff374', 'extended_service_name': 'POP3S', 'port': 110}, {'transport_protocol': 'TCP', 'service_name': 'PORTMAP', 'extended_service_name': 'PORTMAP', 'port': 111}, {'transport_protocol': 'UDP', 'extended_service_name': 'PORTMAP', 'service_name': 'PORTMAP', 'port': 111}, {'extended_service_name': 'IMAPS', 'transport_protocol': 'TCP', 'service_name': 'IMAP', 'certificate': 'af3e698630d34e665cd9712264a75a2e122069e98a90bf875760f7d4688ff374', 'port': 143}, {'extended_service_name': 'HTTPS', 'transport_protocol': 'TCP', 'service_name': 'HTTP', 'certificate': 'af3e698630d34e665cd9712264a75a2e122069e98a90bf875760f7d4688ff374', 'port': 443}, {'transport_protocol': 'TCP', 'service_name': 'SMTP', 'extended_service_name': 'SMTP', 'port': 587}, {'service_name': 'IMAP', 'transport_protocol': 'TCP', 'certificate': 'af3e698630d34e665cd9712264a75a2e122069e98a90bf875760f7d4688ff374', 'extended_service_name': 'IMAPS', 'port': 993}, {'service_name': 'POP3', 'transport_protocol': 'TCP', 'certificate': 'af3e698630d34e665cd9712264a75a2e122069e98a90bf875760f7d4688ff374', 'extended_service_name': 'POP3S', 'port': 995}, {'transport_protocol': 'TCP', 'service_name': 'HTTP', 'extended_service_name': 'HTTP', 'port': 2077}, {'certificate': 'af3e698630d34e665cd9712264a75a2e122069e98a90bf875760f7d4688ff374', 'transport_protocol': 'TCP', 'extended_service_name': 'HTTPS', 'service_name': 'HTTP', 'port': 2078}, {'transport_protocol': 'TCP', 'extended_service_name': 'HTTP', 'service_name': 'HTTP', 'port': 2079}, {'extended_service_name': 'HTTPS', 'transport_protocol': 'TCP', 'service_name': 'HTTP', 'certificate': 'af3e698630d34e665cd9712264a75a2e122069e98a90bf875760f7d4688ff374', 'port': 2080}, {'transport_protocol': 'TCP', 'extended_service_name': 'HTTP', 'service_name': 'HTTP', 'port': 2082}, {'transport_protocol': 'TCP', 'extended_service_name': 'HTTP', 'service_name': 'HTTP', 'port': 2083} ...
# {'code': 200, 'status': 'OK', 'result': {'query': '("no prescription required" OR "no prescription needed" OR "without prescriptionno rx needed" OR "no rx required" OR "no doctor visit") OR ("viagra" OR "cialis" OR "levitra" OR "kamagra" OR "sildenafil" OR "tadalafil" OR "vardenafil" OR "stendra" OR "xanax" OR "valium" OR "tramadol" OR "oxycodone" OR "hydrocodone" OR "percocet" OR "adderall" OR "fentanyl" OR "morphine" OR "codeine" OR "hydromorphone" OR "oxymorphone" OR "dilaudid" OR "suboxone" OR "buprenorphine" OR "oxicontin" OR "vicodin" OR "roxicodone")', 'total': 2941, 'duration': 308, 'hits': [{'location': {'coordinates': {'latitude': 55.75222, 'longitude': 37.61556}, 'province': 'Moscow', 'timezone': 'Europe/Moscow', 'country': 'Russia', 'continent': 'Europe', 'city': 'Moscow', 'country_code': 'RU', 'postal_code': '101000'}, 'last_updated_at': '2025-05-31T15:42:20.543Z', 'autonomous_system': {'description': 'STOLICA', 'bgp_prefix': '213.21.220.0/24', 'asn': 51017, 'country_code': 'RU', 'name': 'STOLICA'}, 'ip': '213.21.220.4', 'dns': {'reverse_dns': {'names': ['valium.xxxxx.lv']}}, 'operating_system': {'other': [{'key': 'family', 'value': 'PIX'}], 'source': 'OSI_APPLICATION_LAYER', 'part': 'o', 'component_uniform_resource_identifiers': [], 'product': 'PIX', 'vendor': 'Cisco', 'cpe': 'cpe:2.3:o:cisco:pix_firewall_software:*:*:*:*:*:*:*:*'}, 'services': [{'service_name': 'SMTP', 'transport_protocol': 'TCP', 'certificate': '62d3f87da7c4689928703e30d33806f5d2db04db94990bd200cd216e27c0bf40', 'extended_service_name': 'SMTP-STARTTLS', 'port': 25}, {'extended_service_name': 'SMTPS', 'transport_protocol': 'TCP', 'service_name': 'SMTP', 'certificate': '62d3f87da7c4689928703e30d33806f5d2db04db94990bd200cd216e27c0bf40', 'port': 465}, {'certificate': '62d3f87da7c4689928703e30d33806f5d2db04db94990bd200cd216e27c0bf40', 'transport_protocol': 'TCP', 'extended_service_name': 'SMTP-STARTTLS', 'service_name': 'SMTP', 'port': 587}], 'matched_services': [{'service_name': 'SMTP', 'transport_protocol': 'TCP', 'certificate': '62d3f87da7c4689928703e30d33806f5d2db04db94990bd200cd216e27c0bf40', 'extended_service_name': 'SMTPS', 'port': 465}, {'service_name': 'SMTP', 'transport_protocol': 'TCP', 'certificate': '62d3f87da7c4689928703e30d33806f5d2db04db94990bd200cd216e27c0bf40', 'extended_service_name': 'SMTP-STARTTLS', 'port': 587}, {'certificate': '62d3f87da7c4689928703e30d33806f5d2db04db94990bd200cd216e27c0bf40', 'transport_protocol': 'TCP', 'extended_service_name': 'SMTP-STARTTLS', 'service_name': 'SMTP', 'port': 25}]}, {'location': {'city': 'Kansas City', 'province': 'Missouri', 'timezone': 'America/Chicago', 'country': 'United States', 'continent': 'North America', 'postal_code': '64170', 'country_code': 'US', 'coordinates': {'latitude': 39.0997, 'longitude': -94.5786}}, 'last_updated_at': '2025-05-31T18:23:45.906Z', 'autonomous_system': {'description': 'WII', 'bgp_prefix': '204.12.192.0/18', 'asn': 32097, 'country_code': 'US', 'name': 'WII'}, 'ip': '204.12.241.234', 'operating_system': {'source': 'OSI_APPLICATION_LAYER', 'other': [{'value': 'Linux', 'key': 'family'}], 'part': 'o', 'component_uniform_resource_identifiers': [], 'product': 'Linux', 'vendor': 'Ubuntu', 'cpe': 'cpe:2.3:o:canonical:ubuntu_linux:*:*:*:*:*:*:*:*'}, 'services': [{'extended_service_name': 'FTPes', 'transport_protocol': 'TCP', 'service_name': 'FTP', 'certificate': '948805c488cccc811d7db7fa9b193b0ad39004daf2900d6d172432eedfe8f4e5', 'port': 21}, {'transport_protocol': 'TCP', 'service_name': 'SSH', 'extended_service_name': 'SSH', 'port': 22}, {'transport_protocol': 'TCP', 'extended_service_name': 'HTTP', 'service_name': 'HTTP', 'port': 80}, {'service_name': 'HTTP', 'transport_protocol': 'TCP', 'certificate': '3ee5f7edb198eb83c0d4109c184b42a15246c2177a1f0ed0c1ecbfdc0dc3fe91', 'extended_service_name': 'HTTPS', 'port': 443}, {'service_name': 'HTTP', 'transport_protocol': 'TCP', 'certificate': 'b636450c3d4568583ad2017a73213b89f0b00d3314c3dd09a133fbdb279aa408', 'extended_service ...
# {'code': 200, 'status': 'OK', 'result': {'query': '("no prescription required" OR "no prescription needed" OR "without prescriptionno rx needed" OR "no rx required" OR "no doctor visit") OR ("viagra" OR "cialis" OR "levitra" OR "kamagra" OR "sildenafil" OR "tadalafil" OR "vardenafil" OR "stendra" OR "xanax" OR "valium" OR "tramadol" OR "oxycodone" OR "hydrocodone" OR "percocet" OR "adderall" OR "fentanyl" OR "morphine" OR "codeine" OR "hydromorphone" OR "oxymorphone" OR "dilaudid" OR "suboxone" OR "buprenorphine" OR "oxicontin" OR "vicodin" OR "roxicodone")', 'total': 2941, 'duration': 332, 'hits': [{'ip': '60.32.104.71', 'location': {'coordinates': {'latitude': 34.69379, 'longitude': 135.50107}, 'province': 'Osaka', 'timezone': 'Asia/Tokyo', 'country': 'Japan', 'continent': 'Asia', 'city': 'Osaka', 'country_code': 'JP', 'postal_code': '543-0062'}, 'last_updated_at': '2024-12-08T02:39:32.845Z', 'autonomous_system': {'description': 'OCN NTT Communications Corporation', 'bgp_prefix': '60.32.0.0/12', 'asn': 4713, 'country_code': 'JP', 'name': 'OCN NTT Communications Corporation'}, 'services': [{'transport_protocol': 'TCP', 'extended_service_name': 'OPENVPN', 'service_name': 'OPENVPN', 'port': 443}]}, {'ip': '60.32.104.66', 'autonomous_system': {'description': 'OCN NTT Communications Corporation', 'bgp_prefix': '60.32.0.0/12', 'asn': 4713, 'country_code': 'JP', 'name': 'OCN NTT Communications Corporation'}, 'last_updated_at': '2024-12-05T21:05:26.141Z', 'location': {'city': 'Osaka', 'province': 'Osaka', 'timezone': 'Asia/Tokyo', 'country': 'Japan', 'continent': 'Asia', 'postal_code': '543-0062', 'country_code': 'JP', 'coordinates': {'latitude': 34.69379, 'longitude': 135.50107}}, 'services': [{'transport_protocol': 'TCP', 'service_name': 'OPENVPN', 'extended_service_name': 'OPENVPN', 'port': 443}]}, {'ip': '13.52.62.22', 'location': {'coordinates': {'latitude': 37.33939, 'longitude': -121.89496}, 'province': 'California', 'timezone': 'America/Los_Angeles', 'country': 'United States', 'continent': 'North America', 'city': 'San Jose', 'country_code': 'US', 'postal_code': '95025'}, 'last_updated_at': '2025-05-31T11:24:24.642Z', 'autonomous_system': {'description': 'AMAZON-02', 'bgp_prefix': '13.52.0.0/16', 'asn': 16509, 'country_code': 'US', 'name': 'AMAZON-02'}, 'services': [{'transport_protocol': 'TCP', 'service_name': 'HTTP', 'extended_service_name': 'HTTP', 'port': 80}, {'extended_service_name': 'HTTPS', 'transport_protocol': 'TCP', 'service_name': 'HTTP', 'certificate': 'ce51fe4057dd22e465046ad694b4f73b9bd77f6945aaeeb5c5ace875ecc25129', 'port': 443}], 'matched_services': [{'service_name': 'HTTP', 'transport_protocol': 'TCP', 'certificate': 'ce51fe4057dd22e465046ad694b4f73b9bd77f6945aaeeb5c5ace875ecc25129', 'extended_service_name': 'HTTPS', 'port': 443}]}, {'last_updated_at': '2025-05-31T14:59:51.167Z', 'autonomous_system': {'description': 'OCN NTT Communications Corporation', 'bgp_prefix': '220.96.0.0/14', 'asn': 4713, 'country_code': 'JP', 'name': 'OCN NTT Communications Corporation'}, 'ip': '220.99.126.98', 'dns': {'reverse_dns': {'names': ['keitai.xanax.jp']}}, 'location': {'coordinates': {'latitude': 34.69379, 'longitude': 135.50107}, 'province': 'Osaka', 'timezone': 'Asia/Tokyo', 'country': 'Japan', 'continent': 'Asia', 'city': 'Osaka', 'country_code': 'JP', 'postal_code': '543-0062'}, 'services': [{'transport_protocol': 'TCP', 'extended_service_name': 'OPENVPN', 'service_name': 'OPENVPN', 'port': 443}]}, {'ip': '60.32.104.70', 'location': {'postal_code': '543-0062', 'province': 'Osaka', 'timezone': 'Asia/Tokyo', 'country': 'Japan', 'continent': 'Asia', 'coordinates': {'latitude': 34.69379, 'longitude': 135.50107}, 'country_code': 'JP', 'city': 'Osaka'}, 'last_updated_at': '2024-12-05T20:41:23.164Z', 'autonomous_system': {'description': 'OCN NTT Communications Corporation', 'bgp_prefix': '60.32.0.0/12', 'asn': 4713, 'country_code': 'JP', 'name': 'OCN NTT Communications Corporation'}, 'services': [{'transport_protocol': 'TCP ...
# {'code': 200, 'status': 'OK', 'result': {'query': '("no prescription required" OR "no prescription needed" OR "without prescriptionno rx needed" OR "no rx required" OR "no doctor visit") OR ("viagra" OR "cialis" OR "levitra" OR "kamagra" OR "sildenafil" OR "tadalafil" OR "vardenafil" OR "stendra" OR "xanax" OR "valium" OR "tramadol" OR "oxycodone" OR "hydrocodone" OR "percocet" OR "adderall" OR "fentanyl" OR "morphine" OR "codeine" OR "hydromorphone" OR "oxymorphone" OR "dilaudid" OR "suboxone" OR "buprenorphine" OR "oxicontin" OR "vicodin" OR "roxicodone")', 'total': 2941, 'duration': 318, 'hits': [{'last_updated_at': '2025-05-31T04:32:01.868Z', 'autonomous_system': {'description': 'AMAZON-AES', 'bgp_prefix': '3.208.0.0/12', 'asn': 14618, 'country_code': 'US', 'name': 'AMAZON-AES'}, 'ip': '3.218.144.74', 'dns': {'reverse_dns': {'names': ['ec2-3-218-144-74.compute-1.amazonaws.com']}}, 'location': {'city': 'Ashburn', 'province': 'Virginia', 'timezone': 'America/New_York', 'country': 'United States', 'continent': 'North America', 'postal_code': '20147', 'country_code': 'US', 'coordinates': {'latitude': 39.04372, 'longitude': -77.48749}}, 'services': [{'transport_protocol': 'TCP', 'extended_service_name': 'HTTP', 'service_name': 'HTTP', 'port': 80}, {'service_name': 'HTTP', 'transport_protocol': 'TCP', 'certificate': '913d1f36522e5eb9275cd95ab2c4443414f10b36327fa4ebb73693f5353850c2', 'extended_service_name': 'HTTPS', 'port': 443}], 'matched_services': [{'extended_service_name': 'HTTPS', 'transport_protocol': 'TCP', 'service_name': 'HTTP', 'certificate': '913d1f36522e5eb9275cd95ab2c4443414f10b36327fa4ebb73693f5353850c2', 'port': 443}]}, {'location': {'postal_code': '07047', 'province': 'New Jersey', 'timezone': 'America/New_York', 'country': 'United States', 'continent': 'North America', 'coordinates': {'latitude': 40.80427, 'longitude': -74.01208}, 'country_code': 'US', 'city': 'North Bergen'}, 'last_updated_at': '2025-05-31T20:12:41.003Z', 'autonomous_system': {'description': 'DIGITALOCEAN-ASN', 'bgp_prefix': '142.93.240.0/20', 'asn': 14061, 'country_code': 'US', 'name': 'DIGITALOCEAN-ASN'}, 'ip': '142.93.253.9', 'operating_system': {'part': 'o', 'component_uniform_resource_identifiers': [], 'product': 'linux', 'other': [], 'cpe': 'cpe:2.3:o:*:linux:*:*:*:*:*:*:*:*', 'source': 'OSI_TRANSPORT_LAYER'}, 'services': [{'transport_protocol': 'TCP', 'extended_service_name': 'FTP', 'service_name': 'FTP', 'port': 21}, {'transport_protocol': 'TCP', 'extended_service_name': 'SSH', 'service_name': 'SSH', 'port': 22}, {'extended_service_name': 'SMTP-STARTTLS', 'transport_protocol': 'TCP', 'service_name': 'SMTP', 'certificate': '6709cf17789ed4608aa90ec56fe09d64bc0637182aab3f2fa5b371e9db5de051', 'port': 25}, {'transport_protocol': 'UDP', 'service_name': 'DNS', 'extended_service_name': 'DNS', 'port': 53}, {'transport_protocol': 'TCP', 'service_name': 'HTTP', 'extended_service_name': 'HTTP', 'port': 80}, {'extended_service_name': 'POP3S', 'transport_protocol': 'TCP', 'service_name': 'POP3', 'certificate': '6709cf17789ed4608aa90ec56fe09d64bc0637182aab3f2fa5b371e9db5de051', 'port': 110}, {'service_name': 'IMAP', 'transport_protocol': 'TCP', 'certificate': '6709cf17789ed4608aa90ec56fe09d64bc0637182aab3f2fa5b371e9db5de051', 'extended_service_name': 'IMAPS', 'port': 143}, {'service_name': 'HTTP', 'transport_protocol': 'TCP', 'certificate': 'c9b07c7b97732c1420539bb5c5cbe5821ca7e7dc6a80cf70d83d67edfefe7e06', 'extended_service_name': 'HTTPS', 'port': 443}, {'certificate': '6709cf17789ed4608aa90ec56fe09d64bc0637182aab3f2fa5b371e9db5de051', 'transport_protocol': 'TCP', 'extended_service_name': 'SMTPS', 'service_name': 'SMTP', 'port': 465}, {'service_name': 'SMTP', 'transport_protocol': 'TCP', 'certificate': '6709cf17789ed4608aa90ec56fe09d64bc0637182aab3f2fa5b371e9db5de051', 'extended_service_name': 'SMTP-STARTTLS', 'port': 587}, {'extended_service_name': 'IMAPS', 'transport_protocol': 'TCP', 'service_name': 'IMAP', 'certificate': '6709cf17789ed4608aa90ec5 ...

# %% [markdown]
# ## Compile Blocklist that Require Post-Processing

# %%
pharmacies = fetch_illegal_pharmacies()
# trim accordingly
blocklist_pharmacy_safe = pharmacies[14:-7]
print(f"Total pharmacies in blocklist: {len(blocklist_pharmacy_safe)}")

# # Write to text file
# with open('data/blocklist_pharmacy_safe.txt', 'w') as f:
#     for entry in blocklist_pharmacy_safe:
#         f.write(entry + '\n')
# Out:
# Total pharmacies in blocklist: 44257

# %%
df_whitelist_pharmacy_safe = pd.read_csv('../data/fig2/whitelist_pharmacy_safe.csv')

whitelist_pharmacy_safe_arr = []
for entry in df_whitelist_pharmacy_safe['NABP Approved Websites'].values:
    for e in entry.split('\n'):
        whitelist_pharmacy_safe_arr.append(e)

# with open('data/whitelist_pharmacy_safe.txt','w') as f:
#     for line in whitelist_pharmacy_safe_arr:
#         f.write(line + '\n')

# %% [markdown]
# ## Covnert DNS Blocklists to IP Blocklists

# %%
# convert_dns_files_to_ip('data/blocklist_pharmacy_safe.txt','data/blocklist_pharmacy_safe_ip.txt')
# convert_dns_files_to_ip('data/blocklist_pharmacy_safe2.txt','data/blocklist_pharmacy_safe2_ip.txt')
# convert_dns_files_to_ip('data/blocklist_pharmacy_list_fda_warnings.txt','data/blocklist_pharmacy_list_fda_warnings_ip.txt')
# convert_dns_files_to_ip('data/whitelist_pharmacy_safe.txt','data/whitelist_pharmacy_safe_ip.txt')
